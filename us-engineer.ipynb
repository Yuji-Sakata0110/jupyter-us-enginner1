# %%
import pandas as pd

df = pd.read_csv("/Users/yujis/Library/Mobile Documents/com~apple~CloudDocs/Documents/dataset/us-software-engineer-jobs-zenrows.csv")

# %%
df
# Out:
#                                                    title  \
# 0                                      Android Developer
# 1                                          Web Developer
# 2                                  Sr. Android Developer
# 3                               Junior Software Engineer
# 4      Cloud Engineer (Software Engineer Advanced, Ex...
# ...                                                  ...
# 58428                               Mobile App Developer
# 58429                    Senior Software Engineer (TCAT)
# 58430                                  Software Engineer
# 58431                         Systems Analyst/Programmer
# 58432                        Senior Engineer II-Software
#
#                                 company                    salary  rating  \
# 0                               Shockoe                       NaN     0.0
# 1                          Denios, Inc.  $45,000 - $55,000 a year     0.0
# ...

# %%
title_count = df['title'].value_counts().head(5)

# %%
title_count
# Out:
# Senior Software Engineer    2957
# Software Engineer           2833
# Sr. Software Engineer        637
# DevOps Engineer              595
# Software Developer           538
# Name: title, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
# カウント結果を棒グラフで可視化
title_count.plot(kind='bar')
plt.title('Title Counts')
plt.xlabel('Title')
plt.ylabel('Count')
plt.show()
